# %% [markdown]
# ## Observations and Insights

# %% [markdown]
# To begin with,Best Tumor reduction over time was under the Capomulin Regimen.
# Secondly,As the Mouse Weight increases, the Tumor size is also observed to increase.
# Lastly,Mouse Sex ratio was almost equal possibly minimizing any affects to the study due to sex.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from sklearn import datasets
from scipy.stats import linregress

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
mice_data = pd.merge(mouse_metadata,study_results)
# Display the data table for preview
mice_data
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice.
tot_mice = mice_data["Mouse ID"].unique()
#Store Each individual mice Id and then print the length.
tot_mice = len(tot_mice)
tot_mice
# Out:
# 249

# %%
# Getting the duplicate entries by mouse ID number that show up for Mouse ID and Timepoint. 
mouse_grouped = mice_data.groupby(["Mouse ID", "Timepoint"]).count()
mouse_grouped

duplicate=mouse_grouped.loc[mouse_grouped["Drug Regimen"]>1]
duplicate
# Out:
#                     Drug Regimen  Sex  Age_months  Weight (g)  \
# Mouse ID Timepoint
# g989     0                     2    2           2           2
#          5                     2    2           2           2
#          10                    2    2           2           2
#          15                    2    2           2           2
#          20                    2    2           2           2
#
#                     Tumor Volume (mm3)  Metastatic Sites
# Mouse ID Timepoint
# g989     0                           2                 2
#          5                           2                 2
#          10                          2                 2
#          15                          2                 2
#          20                          2                 2

# %%
#Credit: https://github.com/JoeKell/
# Optional: Get all the data for the duplicate mouse ID. 
mice_data.loc[mice_data["Mouse ID"]=="g989",:]
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
# 918     g989     Propriva  Female          21          26         25
# 919     g989     Propriva  Female          21          26         30
# 920     g989     Propriva  Female          21          26         35
#
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
mice_data_cleaned=mice_data[mice_data["Mouse ID"] != 'g989']
mice_data_cleaned
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.
tot_mice2 = mice_data_cleaned["Mouse ID"].unique()
#Store Each individual mice Id and then print the length.
tot_mice2 = len(tot_mice2)
tot_mice2
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, 
# and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 

# Mean of the tumor volume
mice_mean = mice_data_cleaned.groupby("Drug Regimen").mean()["Tumor Volume (mm3)"]

# Median of the tumor volume
mice_med = mice_data_cleaned.groupby("Drug Regimen").median()["Tumor Volume (mm3)"]

# variance of the tumor volume
mice_var = mice_data_cleaned.groupby("Drug Regimen").var()["Tumor Volume (mm3)"]

# Standard Deviation of the tumor volume
mice_std = mice_data_cleaned.groupby("Drug Regimen").std()["Tumor Volume (mm3)"]

# SEM of the tumor volume
mice_sem = mice_data_cleaned.groupby("Drug Regimen").sem()["Tumor Volume (mm3)"]


# Assemble the resulting series into a single summary dataframe.
mice_summ = pd.DataFrame({
    "Mean": mice_mean,
    "Median": mice_med,
    "Variance": mice_var,
    "Standard Deviation": mice_std,
    "SEM": mice_sem
})

mice_summ
# Out:
#                    Mean     Median   Variance  Standard Deviation       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764            4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177            6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684            6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577            8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479            8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083            7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013            6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704            4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562            7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355            6.966589  0.516398

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# Using the aggregation method, produce the same summary statistics in a single line

mice_summ2=mice_data_cleaned[["Drug Regimen","Tumor Volume (mm3)"]].groupby(["Drug Regimen"]).agg(['mean','median','var','std','sem'])
mice_summ2
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using Pandas.
mice_reg = mice_data_cleaned.groupby(["Drug Regimen"])
timepoint_count = mice_reg.count()
#Store the X and Y variables
timepoint = timepoint_count.plot.bar(y="Timepoint", rot=45,figsize=(9,6), color='r',fontsize = 8)
timepoint.set_xlabel("Drug Regimen",fontsize = 14)
timepoint.set_ylabel("Timepoints",fontsize = 14)
timepoint.set_title("Timepoints per Drug Regimen",fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Timepoints per Drug Regimen')

# %%
mice_reg2 = mice_data_cleaned.groupby(["Drug Regimen"])["Timepoint"].count()

# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using pyplot.
plt.bar(mice_reg2.index,mice_reg2.values)
plt.xticks(rotation = 45)
plt.xlabel("Regimen")
plt.ylabel("Timepoints")
plt.ylim(0,240)
plt.title("Timepoints per Mouse")
# Out:
# Text(0.5, 1.0, 'Timepoints per Mouse')

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
#Segregate by sex
m_sex= mice_data_cleaned.groupby(["Sex"]).count()
#Plot the pie chart
m_sex.plot(kind = "pie", y = "Mouse ID", title = "Male vs Female Mice", figsize = (5,6),
              startangle = 180,autopct="%1.1f%%",colors = (['red', 'cyan']),shadow=True)

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
#Set the lables
m_sex2 = ["Female", "Male"]
#Plot using Pyplot
plt.pie(x=m_sex["Mouse ID"],labels=m_sex2,radius=1.35,autopct="%1.1f%%",colors = (['red', 'cyan']),startangle = 180,shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x254fa6f7948>,
# ...
#  [Text(-0.04466071901153093, -1.4843282723768938, 'Female'),
#   Text(0.04466071901153111, 1.4843282723768938, 'Male')],
#  [Text(-0.024360392188107777, -0.8096336031146693, '49.0%'),
#   Text(0.024360392188107875, 0.8096336031146693, '51.0%')])

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
regimen = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]
mice_vol = []



# Start by getting the last (greatest) timepoint for each mouse
l_m = mice_data_cleaned.groupby(["Mouse ID"])["Timepoint"].max()
l_m_df = pd.DataFrame(l_m)


# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
lm2 = pd.merge(mice_data_cleaned, l_m_df, on = ("Mouse ID", "Timepoint"), how = "right")
lm2
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0       k403     Ramicane    Male          21          16         45
# 1       s185    Capomulin  Female           3          17         45
# 2       x401    Capomulin  Female          16          15         45
# 3       m601    Capomulin    Male          22          17         45
# 4       g791     Ramicane    Male          11          16         45
# ..       ...          ...     ...         ...         ...        ...
# 243     z314     Stelasyn  Female          21          28          5
# 244     z435     Propriva  Female          12          26         10
# 245     z581    Infubinol  Female          24          25         45
# 246     z795     Naftisol  Female          13          29         45
# 247     z969     Naftisol    Male           9          30         45
#
#      Tumor Volume (mm3)  Metastatic Sites
# 0             22.050126                 1
# 1             23.343598                 1
# ...

# %%
# Put treatments into a list for a for loop (and later for plot labels)

    
# Determine outliers using upper and lower bounds
   

# Create empty list to fill with tumor vol data (for plotting)
#Run a loop and append tumor values by regimen
for x in regimen:
    regi_df = lm2.loc[lm2["Drug Regimen"] == x,"Tumor Volume (mm3)"]
    mice_vol.append(regi_df)
    
# Calculate the IQR and quantitatively determine if there are any potential outliers.
m_quart = regi_df.quantile([0.25,0.5,0.75])

m_l_q = m_quart[0.25]

m_u_q = m_quart[0.75]

m_iqr = m_u_q - m_l_q

m_ubound = m_u_q + (1.5*m_iqr)

m_lbound = m_l_q - (1.5*m_iqr)

# Determine outliers using upper and lower bounds   
outliers = regi_df.loc[(regi_df < m_lbound)|(regi_df > m_ubound)]

# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
fig1, bp1 = plt.subplots()
bp1.set_title('Tumor Volumes at Last Timepoints (with outliers)')
bp1.set_ylabel('Tumor Volume (mm3)')
bp1.boxplot(mice_vol,regimen)
plt.show()
   
print(outliers)
# Out:
# Series([], Name: Tumor Volume (mm3), dtype: float64)

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. timepoint for a mouse treated with Capomulin
#Isolate mice under Capomulin Regimen
Cap_m_df = mice_data_cleaned.loc[mice_data_cleaned["Drug Regimen"] == "Capomulin",:]

#Pick any Mouse under Regimen
x401_df = Cap_m_df.loc[Cap_m_df["Mouse ID"] == "x401",:]
x401_df.head()

#Plot a line chart showcasing the tumorsize as time spent on Regimen increases
plt.plot(x401_df["Timepoint"], x401_df["Tumor Volume (mm3)"],color = "green")
plt.title("MOUSE x401")
plt.xlabel("Timepoint")
plt.ylabel("Tumor Volume (mm3)")
# Out:
# Text(0, 0.5, 'Tumor Volume (mm3)')

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
fig1, bp2 = plt.subplots()

#Get mean of all Mice under Capomulin regimen
capmean_vol =Cap_m_df.groupby(['Mouse ID']).mean()

plt.scatter(capmean_vol['Weight (g)'],capmean_vol['Tumor Volume (mm3)'], color="red")
plt.title('Average tumor volume vs. Mouse weight')
plt.xlabel(' Mouse weight(g)')
plt.ylabel('Average tumor volume(mm3)')
# Out:
# Text(0, 0.5, 'Average tumor volume(mm3)')

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient 
# for mouse weight and average tumor volume for the Capomulin regimen
m_corr = st.pearsonr(capmean_vol['Weight (g)'], capmean_vol['Tumor Volume (mm3)'])

m_corr
print(f"Correlation is {round(m_corr[0],2)}")

#linear regression model 
x_values = capmean_vol['Weight (g)']
y_values = capmean_vol['Tumor Volume (mm3)']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(line_eq)

plt.scatter(capmean_vol['Weight (g)'],capmean_vol['Tumor Volume (mm3)'], color='orange')
plt.title('Average tumor volume vs. Mouse weight')
plt.xlabel(' Mouse weight(g)')
plt.ylabel('Average tumor volume(mm3)')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (20,38), fontsize = 12, color = "red")
# Out:
# Correlation is 0.84
# y = 0.95x + 21.55
# Text(20, 38, 'y = 0.95x + 21.55')
